# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import statsmodels.api as sm
from scipy.stats import boxcox
import xlrd
import datetime as dt
pd.options.display.max_rows = 50

# %%
df_ca = pd.read_csv('Data/Data_Marketing_Customer_Analysis_Round2.csv')

# %%
df_ca
# Out:
#        Unnamed: 0 Customer       State  Customer Lifetime Value Response  \
# 0               0  DK49336     Arizona              4809.216960       No
# 1               1  KX64629  California              2228.525238       No
# 2               2  LZ68649  Washington             14947.917300       No
# 3               3  XL78013      Oregon             22332.439460      Yes
# 4               4  QA50777      Oregon              9025.067525       No
# ...           ...      ...         ...                      ...      ...
# 10905       10905  FE99816      Nevada             15563.369440       No
# 10906       10906  KX53892      Oregon              5259.444853       No
# 10907       10907  TL39050     Arizona             23893.304100       No
# 10908       10908  WA60547  California             11971.977650       No
# 10909       10909  IV32877         NaN              6857.519928      NaN
#
#        Coverage Education Effective To Date EmploymentStatus Gender  ...  \
# ...

# %%
#df_ca.select_dtypes(include= np.number).columns.tolist()

# %%
def drop_customer(df_ca):
    df_ca.drop(columns="Unnamed: 0", inplace=True)
    return df_ca

# %%
drop_customer(df_ca)
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
df_ca['Month'] = pd.DatetimeIndex(df_ca['Effective To Date']).month_name()

# %%
# da_cf1 = df_ca[df_ca['Month'].dt.quarter.isin[1]]?
#df_ca[df_ca['Month'].month_name() == ["January", "February", "March"]['Month']] ?
#df_ca['Month']=pd.to_datetime(df_ca['Month'], errors = 'ignore')
df_ca
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
da_cf1 = df_ca[df_ca['Month'].isin(["January", "February", "March"])]

# %%
da_cf1
# Out:
#       Customer       State  Customer Lifetime Value Response  Coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877         NaN              6857.519928      NaN     Basic
#
#       Education Effective To Date EmploymentStatus Gender  Income  ...  \
# ...

# %%
categoricals= df_ca.select_dtypes("object")

# %%
categoricals
# Out:
#       Customer       State Response  Coverage Education Effective To Date  \
# 0      DK49336     Arizona       No     Basic   College           2/18/11
# 1      KX64629  California       No     Basic   College           1/18/11
# 2      LZ68649  Washington       No     Basic  Bachelor           2/10/11
# 3      XL78013      Oregon      Yes  Extended   College           1/11/11
# 4      QA50777      Oregon       No   Premium  Bachelor           1/17/11
# ...        ...         ...      ...       ...       ...               ...
# 10905  FE99816      Nevada       No   Premium  Bachelor           1/19/11
# 10906  KX53892      Oregon       No     Basic   College            1/6/11
# 10907  TL39050     Arizona       No  Extended  Bachelor            2/6/11
# 10908  WA60547  California       No   Premium   College           2/13/11
# 10909  IV32877         NaN      NaN     Basic  Bachelor            1/8/11
#
#       EmploymentStatus Gender Location Code Marital Status     Policy Type  \
# ...

# %%
numerical= df_ca.select_dtypes(np.number)

# %%
numerical
# Out:
#        Customer Lifetime Value  Income  Monthly Premium Auto  \
# 0                  4809.216960   48029                    61
# 1                  2228.525238       0                    64
# 2                 14947.917300   22139                   100
# 3                 22332.439460   49078                    97
# 4                  9025.067525   23675                   117
# ...                        ...     ...                   ...
# 10905             15563.369440       0                   253
# 10906              5259.444853   61146                    65
# 10907             23893.304100   39837                   201
# 10908             11971.977650   64195                   158
# 10909              6857.519928       0                   101
#
#        Months Since Last Claim  Months Since Policy Inception  \
# 0                          7.0                             52
# 1                          3.0                             26
# ...

# %%
numerical.hist(figsize=(12,12))
sns.displot(numerical, x= "Income")

# %%
fig, axes = plt.subplots(3,3,figsize=(14,12))
sns.histplot(numerical, x=numerical.iloc[:,0], ax = axes[0,0])
sns.histplot(numerical, x=numerical.iloc[:,1], ax = axes[0,1])
sns.histplot(numerical, x=numerical.iloc[:,2], ax = axes[0,2])
sns.histplot(numerical, x=numerical.iloc[:,3], ax = axes[1,0])
sns.histplot(numerical, x=numerical.iloc[:,4], ax = axes[1,1])
sns.histplot(numerical, x=numerical.iloc[:,5], ax = axes[1,2])
sns.histplot(numerical, x=numerical.iloc[:,6], ax = axes[2,0])
sns.histplot(numerical, x=numerical.iloc[:,7], ax = axes[2,1])
# Out:
# <AxesSubplot:xlabel='Total Claim Amount', ylabel='Count'>

# %%
numerical.iloc[:,1]
# Out:
# 0        48029
# 1            0
# 2        22139
# 3        49078
# 4        23675
#          ...
# 10905        0
# 10906    61146
# 10907    39837
# 10908    64195
# 10909        0
# Name: Income, Length: 10910, dtype: int64

# %%
def distrib_plots(numerical):
    plt.figure(figsize = (14,12))
    for i, col in enumerate(numerical.columns, 1):
        plt.subplot(3,3,i)
        sns.distplot(numerical[col])

# %%
#distrib_plots(numerical)

# %%
sns.distplot((numerical['Monthly Premium Auto']), bins=20)
# Out:
# /Users/macbookpro/opt/anaconda3/envs/DA_ENV/lib/python3.9/site-packages/seaborn/distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Monthly Premium Auto', ylabel='Density'>

# %%
#multicollinearity
#sns.pairplot(numerical)

# %%
numerical.corr()
# Out:
#                                Customer Lifetime Value    Income  \
# Customer Lifetime Value                       1.000000  0.028306
# Income                                        0.028306  1.000000
# Monthly Premium Auto                          0.403069 -0.009788
# Months Since Last Claim                       0.016052 -0.023814
# Months Since Policy Inception                 0.016960 -0.005903
# Number of Open Complaints                    -0.032243  0.007163
# Number of Policies                            0.016024 -0.009960
# Total Claim Amount                            0.232626 -0.354141
#
#                                Monthly Premium Auto  Months Since Last Claim  \
# Customer Lifetime Value                    0.403069                 0.016052
# Income                                    -0.009788                -0.023814
# Monthly Premium Auto                       1.000000                 0.008744
# ...

# %%
corr = numerical.corr()
mask = np.zeros_like(corr)
mask[np.triu_indices_from(mask)] = True
with sns.axes_style("white"):
    f, ax = plt.subplots(figsize=(9, 7))
    ax = sns.heatmap(corr, mask=mask,cmap='coolwarm', vmin=-1,vmax=1,annot=True, square=True)

# %%
#response = categoricals["Response"].value_counts()
#response

# %%
#plt.bar(response.index, height=2, data= response)

# %%
#plt.plot("response", data= categoricals)
#sns.countplot(x="Response", data=categoricals)

# %%
#sns.catplot(x="Response", kind="count", palette="ch:.25", data=categoricals)

# %%
total_claim_amounts_bins = pd.cut(df_ca["Total Claim Amount"], bins=4, labels=["up to 723", "724-1446", "1447-2169", "2169-2894"])
total_claim_amounts_bins
# Out:
# 0        up to 723
# 1         724-1446
# 2        up to 723
# 3        up to 723
# 4        up to 723
#            ...
# 10905     724-1446
# 10906    up to 723
# 10907    up to 723
# 10908    up to 723
# 10909     724-1446
# Name: Total Claim Amount, Length: 10910, dtype: category
# Categories (4, object): ['up to 723' < '724-1446' < '1447-2169' < '2169-2894']

# %%
fig2, axes2 = plt.subplots(2,2, figsize = (10,10))
axes2[0,1].set_title('response rate by sales channel', fontweight='bold')
sns.countplot(x=categoricals["Sales Channel"], y= None, hue= categoricals["Response"], data = categoricals, ax = axes2[0,1])
sns.countplot(x="Response", data=categoricals, ax = axes2[0,0])
axes2[0,0].set_title('Responses', fontweight='bold')
axes2[1,0].set_title('Response rate by total claim amount', fontweight='bold')
sns.countplot(x=total_claim_amounts_bins, y= None, hue= df_ca["Response"], data = df_ca, ax=axes2[1,0])
sns.boxplot(x=df_ca["Response"], y =df_ca["Income"], ax= axes2[1,1])
axes2[1,1].set_title('Response rate by total claim amount', fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Response rate by total claim amount')

# %%
fig3, axes3 = plt.subplots(figsize = (5,5))
#axes3.set_title('response rate by total claim amount', fontweight='bold')
sns.countplot(x=total_claim_amounts_bins, y= None, hue= df_ca["Response"], data = df_ca, ax=axes3)

# %%
#sns.boxplot(x=df_ca["Response"], y =df_ca["Total Claim Amount"])

# %%
#sns.boxplot(x=df_ca["Response"], y =df_ca["Income"])

# %%
fig4, axes4 = plt.subplots(1,2, figsize = (14,6))
axes4[0].set_title('Customer LTV by Policy Type and Gender', fontweight='bold')
#sns.boxplot(x=df_ca["Response"], y =df_ca["Income"], ax= axes2[1,1])
sns.barplot(y= df_ca["Customer Lifetime Value"], x=df_ca["Policy Type"], hue=df_ca["Gender"], ax = axes4[0])

axes4[1].set_title('Monthly Premium Auto by Vehicle Class', fontweight='bold')
sns.barplot(y= numerical["Monthly Premium Auto"], x=df_ca["Vehicle Class"], ax = axes4[1])
# Out:
# <AxesSubplot:title={'center':'Monthly Premium Auto by Vehicle Class'}, xlabel='Vehicle Class', ylabel='Monthly Premium Auto'>
