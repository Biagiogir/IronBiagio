# %% [markdown]
# # Using Pandas

# %%
import pandas as pd
import numpy as np
pd.set_option('display.max_rows', 200)
## to make it possible to display multiple output inside one cell 
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# <b>load the data from the vehicles.csv file into pandas data frame

# %%
## Your Code here
cars = pd.read_csv("data/vehicles.csv")
pd.read_csv("data/vehicles.csv")
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# First exploration of the dataset:
#
# - How many observations does it have?
# - Look at all the columns: do you understand what they mean?
# - Look at the raw data: do you see anything weird?
# - Look at the data types: are they the expected ones for the information the column contains?

# %%
## Your Code here
num_obs = cars.count()
print(num_obs)
cars.info()
# Out:
# Make                       35952
# Model                      35952
# Year                       35952
# Engine Displacement        35952
# Cylinders                  35952
# Transmission               35952
# Drivetrain                 35952
# Vehicle Class              35952
# Fuel Type                  35952
# Fuel Barrels/Year          35952
# City MPG                   35952
# Highway MPG                35952
# Combined MPG               35952
# CO2 Emission Grams/Mile    35952
# Fuel Cost/Year             35952
# dtype: int64
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
# ...

# %%
cars.describe()
# Out:
#               Year  Engine Displacement     Cylinders  Fuel Barrels/Year  \
# count  35952.00000         35952.000000  35952.000000       35952.000000
# mean    2000.71640             3.338493      5.765076          17.609056
# std       10.08529             1.359395      1.755268           4.467283
# min     1984.00000             0.600000      2.000000           0.060000
# 25%     1991.00000             2.200000      4.000000          14.699423
# 50%     2001.00000             3.000000      6.000000          17.347895
# 75%     2010.00000             4.300000      6.000000          20.600625
# max     2017.00000             8.400000     16.000000          47.087143
#
#            City MPG   Highway MPG  Combined MPG  CO2 Emission Grams/Mile  \
# count  35952.000000  35952.000000  35952.000000             35952.000000
# mean      17.646139     23.880646     19.929322               475.316339
# std        4.769349      5.890876      5.112409               119.060773
# ...

# %%
#df_veh["Make"].value_counts()
sorted(set(cars["Make"]))
# Out:
# ['AM General',
#  'ASC Incorporated',
#  'Acura',
#  'Alfa Romeo',
#  'American Motors Corporation',
#  'Aston Martin',
#  'Audi',
#  'Aurora Cars Ltd',
#  'Autokraft Limited',
#  'BMW',
#  'BMW Alpina',
#  'Bentley',
#  'Bertone',
#  'Bill Dovell Motor Car Company',
#  'Bitter Gmbh and Co. Kg',
#  'Bugatti',
#  'Buick',
#  'CCC Engineering',
#  'CX Automotive',
#  'Cadillac',
#  'Chevrolet',
#  'Chrysler',
#  'Consulier Industries Inc',
#  'Dabryan Coach Builders Inc',
#  'Dacia',
#  'Daewoo',
#  'Daihatsu',
#  'Dodge',
#  'E. P. Dutton, Inc.',
#  'Eagle',
#  'Environmental Rsch and Devp Corp',
#  'Evans Automobiles',
#  'Excalibur Autos',
#  'Federal Coach',
#  'Ferrari',
#  'Fiat',
#  'Fisker',
#  'Ford',
#  'GMC',
#  'General Motors',
#  'Genesis',
#  'Geo',
#  'Goldacre',
#  'Grumman Allied Industries',
#  'Grumman Olson',
#  'Honda',
#  'Hummer',
#  'Hyundai',
#  'Import Foreign Auto Sales Inc',
#  'Import Trade Services',
#  'Infiniti',
#  'Isis Imports Ltd',
#  'Isuzu',
# ...

# %% [markdown]
# ### Cleaning and wrangling data
#
# - Some car brand names refer to the same brand. Replace all brand names that contain the word "Dutton" for simply "Dutton". If you find similar examples, clean their names too. Use `loc` with boolean indexing.
#
# - Convert CO2 Emissions from Grams/Mile to Grams/Km
#
# - Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` and .
#
# - convert MPG columns to km_per_liter

# %%
## Your Code here
cars["Make"][cars["Make"].str.contains("Dutton")] = "Dutton"
cars["Make"][cars["Make"].str.contains("BMW")] = "BMW"
cars["Make"][cars["Make"].str.contains("Grumman")] = "Grumman"
cars["Make"][cars["Make"].str.contains("AS, Inc")] = "AS, Inc"
cars["Make"][cars["Make"].str.contains("Saleen")] = "Saleen"
# Out:
# /var/folders/2c/wl35d59s78q2s8_vnnh5zj3c0000gn/T/ipykernel_91598/2559284433.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars["Make"][cars["Make"].str.contains("Dutton")] = "Dutton"
# /var/folders/2c/wl35d59s78q2s8_vnnh5zj3c0000gn/T/ipykernel_91598/2559284433.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   cars["Make"][cars["Make"].str.contains("BMW")] = "BMW"
# /var/folders/2c/wl35d59s78q2s8_vnnh5zj3c0000gn/T/ipykernel_91598/2559284433.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 35952 entries, 0 to 35951
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Make                     35952 non-null  object
#  1   Model                    35952 non-null  object
#  2   Year                     35952 non-null  int64
#  3   Engine Displacement      35952 non-null  float64
#  4   Cylinders                35952 non-null  float64
#  5   Transmission             35952 non-null  object
#  6   Drivetrain               35952 non-null  object
#  7   Vehicle Class            35952 non-null  object
#  8   Fuel Type                35952 non-null  object
#  9   Fuel Barrels/Year        35952 non-null  float64
#  10  City MPG                 35952 non-null  int64
#  11  Highway MPG              35952 non-null  int64
#  12  Combined MPG             35952 non-null  int64
#  13  CO2 Emission Grams/Mile  35952 non-null  float64
# ...

# %%
cars['CO2 Emission Grams/Km'] = cars["CO2 Emission Grams/Mile"] / 1.60934
cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
# Create a binary column that solely indicates if the transmission of a car is automatic or manual. Use `pandas.Series.str.startswith` 
cars["Transmission1"] = cars["Transmission"].map(lambda x : "automatic" if "Auto" in x else "manual")
cars
#cars["Transmission1"] = list(map(lambda x: "Auto if(x.startswith("Auto)) else "Manual", cars["Transmission""]))
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %%
## convert MPG columns to km_per_liter
cars["Combined KPL"] = cars["Combined MPG"] * 1.60934/3.78541
cars
# Out:
#                    Make                Model  Year  Engine Displacement  \
# 0            AM General    DJ Po Vehicle 2WD  1984                  2.5
# 1            AM General     FJ8c Post Office  1984                  4.2
# 2            AM General  Post Office DJ5 2WD  1985                  2.5
# 3            AM General  Post Office DJ8 2WD  1985                  4.2
# 4      ASC Incorporated                  GNX  1987                  3.8
# ...                 ...                  ...   ...                  ...
# 35947             smart         fortwo coupe  2013                  1.0
# 35948             smart         fortwo coupe  2014                  1.0
# 35949             smart         fortwo coupe  2015                  1.0
# 35950             smart         fortwo coupe  2016                  0.9
# 35951             smart         fortwo coupe  2016                  0.9
#
#        Cylinders     Transmission        Drivetrain  \
# ...

# %% [markdown]
# Converting Grams/Mile to Grams/Km
#
# 1 Mile = 1.60934 Km
#
# Grams/Mile * Mile/Km -> Grams/Mile * 1 Mile/1.60934Km
#
# $$ \frac{Grams}{Mile} * \frac{Mile}{Km} $$
#
# $$ \frac{Grams}{Mile} * \frac{1 Mile}{1.60934Km}  $$

# %% [markdown]
# convert MPG columns to km_per_liter
#
# MPG = Miles/Gallon -> Km/Liter
#
# 1 Mile = 1.60934 Km
#
# 1 Gallon = 3.78541 Liters
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{Km}{Miles} * \frac{Gallon}{Liters}$$
#
# $$ \frac{Miles}{Gallon} -> \frac{Miles}{Gallon} * \frac{1.60934Km}{ 1Miles} * \frac{1 Gallon}{3.78541 Liters}$$
#
# * ( 1.60934 / 3.78541 )

# %% [markdown]
# ### Gathering insights:
#
# - How many car makers are there? How many models? Which car maker has the most cars in the dataset?
#
# - When were these cars made? How big is the engine of these cars?
#
# - What's the frequency of different transmissions, drivetrains and fuel types?
#
# - What's the car that consumes the least/most fuel?

# %%
numberofCM = len(cars.Make.value_counts())
numberofCM
numberofModels = len(cars.Model.value_counts())
print(numberofModels)
Maker_mostcars = cars['Make'].value_counts().index[0]
print(Maker_mostcars)
# Out:
# 122
# 3608
# Chevrolet

# %%
Years = cars['Year'].value_counts()
Years
# Out:
# 1985    1581
# 2015    1264
# 2016    1228
# 2014    1211
# 1987    1198
# 1986    1188
# 2008    1184
# 2009    1183
# 2013    1168
# 2005    1156
# 2012    1139
# 1989    1127
# 2007    1126
# 2011    1124
# 1991    1122
# 1988    1119
# 2004    1113
# 2010    1108
# 1992    1107
# 2006    1099
# 1993    1077
# 1990    1068
# 2003    1034
# 1994     967
# 2002     961
# 1995     928
# 2001     902
# 2017     857
# 1999     828
# 2000     827
# 1998     791
# 1996     767
# 1997     755
# 1984     645
# Name: Year, dtype: int64

# %%
Engine_Displacement = cars["Engine Displacement"].value_counts()

# %%
Transmissionfreq = cars["Transmission"].value_counts()
Fuel = cars['Fuel Type'].value_counts()

# %%
Models = cars["Model"].value_counts()
Models
# Out:
# F150 Pickup 2WD      197
# F150 Pickup 4WD      179
# Truck 2WD            173
# Mustang              170
# Jetta                169
#                     ...
# C300 Convertible       1
# C300 Coupe             1
# C300 FFV               1
# C320 4matic Sedan      1
# DJ Po Vehicle 2WD      1
# Name: Model, Length: 3608, dtype: int64

# %%
##car that consume the most/ less

cars[ cars['Fuel Barrels/Year'] == cars['Fuel Barrels/Year'].max()]

cars[ cars['Fuel Barrels/Year'] == cars['Fuel Barrels/Year'].min()]

#cars[Make].value_counts(.index.str.contains("Dutton"))
# Out:
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 20894  Lamborghini  Countach  1986                  5.2       12.0
# 20895  Lamborghini  Countach  1987                  5.2       12.0
# 20896  Lamborghini  Countach  1988                  5.2       12.0
# 20897  Lamborghini  Countach  1989                  5.2       12.0
# 20898  Lamborghini  Countach  1990                  5.2       12.0
#
#        Transmission        Drivetrain Vehicle Class Fuel Type  \
# 20894  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20895  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20896  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20897  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
# 20898  Manual 5-spd  Rear-Wheel Drive   Two Seaters   Premium
#
#        Fuel Barrels/Year  City MPG  Highway MPG  Combined MPG  \
# 20894          47.087143         6           10             7
# ...

# %% [markdown]
# What brand has the worse CO2 Emissions on average?
#
# Hint: use the function `sort_values()`

# %%
cars.sort_values("CO2 Emission Grams/Km")
# Out:
#               Make     Model  Year  Engine Displacement  Cylinders  \
# 3071           BMW    i3 REX  2016                  0.6        2.0
# 3069           BMW    i3 REX  2014                  0.6        2.0
# 3070           BMW    i3 REX  2015                  0.6        2.0
# 7916     Chevrolet      Volt  2016                  1.5        4.0
# 7917     Chevrolet      Volt  2017                  1.5        4.0
# ...            ...       ...   ...                  ...        ...
# 20897  Lamborghini  Countach  1989                  5.2       12.0
# 20894  Lamborghini  Countach  1986                  5.2       12.0
# 20898  Lamborghini  Countach  1990                  5.2       12.0
# 20896  Lamborghini  Countach  1988                  5.2       12.0
# 20895  Lamborghini  Countach  1987                  5.2       12.0
#
#                            Transmission         Drivetrain    Vehicle Class  \
# 3071                     Automatic (A1)   Rear-Wheel Drive  Subcompact Cars
# ...

# %%
## your Code here
cars.groupby('Make')['CO2 Emission Grams/Km'].mean()
# Out:
# Make
# AM General                          379.881345
# AS, Inc                             394.438536
# ASC Incorporated                    345.133719
# Acura                               262.583000
# Alfa Romeo                          288.287195
# American Motors Corporation         314.264744
# Aston Martin                        417.946348
# Audi                                280.087391
# Aurora Cars Ltd                     368.142634
# Autokraft Limited                   334.982728
# BMW                                 284.384482
# Bentley                             426.290692
# Bertone                             251.006341
# Bill Dovell Motor Car Company       324.831736
# Bitter Gmbh and Co. Kg              352.803358
# Bugatti                             542.497235
# Buick                               269.963993
# CCC Engineering                     368.142634
# CX Automotive                       343.312774
# Cadillac                            308.375552
# ...

# %%
cars.groupby('Make')['CO2 Emission Grams/Km'].mean().sort_values()
# Out:
# Make
# Fisker                              105.011992
# smart                               153.498052
# Fiat                                189.311494
# Daihatsu                            192.742404
# MINI                                194.935105
# Scion                               205.920389
# Geo                                 209.450825
# Yugo                                221.251107
# Honda                               222.160996
# Renault                             223.586374
# Saturn                              233.832051
# Hyundai                             239.241983
# Dacia                               240.093022
# Red Shift Ltd.                      240.093022
# Daewoo                              240.941937
# Grumman                             242.101035
# Kia                                 242.732303
# Volkswagen                          244.038998
# Suzuki                              244.042612
# Panoz Auto-Development              251.006341
# ...

# %% [markdown]
# Do cars with automatic transmission consume more fuel than cars with manual transmission on average?

# %%
## Your Code is here 
cars.groupby("Transmission1")["Combined MPG"].mean()
# Out:
# Transmission1
# automatic    19.350926
# manual       21.134025
# Name: Combined MPG, dtype: float64
